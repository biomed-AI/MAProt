# %%
import pickle

# %%
dpo_train_dict_curated = pickle.load(open("./dpo_train_dict_curated.pkl",'rb'))
dpo_train_dict_curated = {k:v for i,(k,v) in enumerate(dpo_train_dict_curated.items()) if i<100}
pickle.dump(dpo_train_dict_curated,open("./dpo_train_dict_curated.pkl",'wb'))

# %%
# dpo_test_dict = pickle.load(open("./dpo_test_dict.pkl",'rb'))
# dpo_test_dict = {k:v for k,v in dpo_test_dict.items() if v[1]=='r6_560_TrROS_Hall.pdb'}
# pickle.dump(dpo_test_dict,open("./dpo_test_dict.pkl",'wb'))
